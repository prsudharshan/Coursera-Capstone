# %% [markdown]
# ## Applied DataScience Capstone Project - Battle of the Neighbourhoods
#
# ### THE GOLD DREGGER
#
# **Sudharshan P.R.**

# %% [markdown]
# ***There is more left after a beer***

# %% [markdown]
# ### PROBLEM DESCRIPTION AND BACKGROUND DISCUSSION
#
# ***The Interesting Background***
#
# In the last decade, major cities in the U.S. have witnessed beer drinkers becoming beer lovers. This led to emergence of various craft brewery establishments that caters to the beer connoisseurs in their respective cities. Undoubtedly craft beers are being guzzled in gallons after gallons. This presents an interesting case for anyone looking beyond after finishing their beers.
#
# The brewing process involves wheat or barley, hops and yeast along with a myriad of flavours. Once the beer portion of the process is extracted, there is the waste portion that remains collected. As it goes with waste from any organic process, this waste is actually wealth. This waste is nutritious since it still contains the solid portion of the ingredients that went into the beer making process.
#
# The spent grains from beer is technically called as dreg(or trub - beer is a global drink - each region will have its term). This dreg isnt as bad as it sounds. In ancient to pre-modern times, this dreg was being fed to animals. And that is how dreg has been used up instead of rotting in a landfill. Interesting there are other uses of this dreg that can be more valueable than just being animal feed.
#
# Here are a few examples of using spent grain from beer making:
#
#     1) Animal feed on farms
#     2) Dreg to baking goods
#     3) Wastewater treatment
#     4) Dreg to compost
#     5) Fish food
#     6) Energy generation (experimental and too technical, hence I am not interested too much in this application)
#
#
#
# ***The Challenging Problem Description***
#
# The big brand commercial beers already have their waste matter handled. Since the factories are located in the rural side, its easy for them to just sell it to the animal farms. The problem faced is by the craft breweries who have to link up with various other businesses to sell-off their dreg.
#
# Here is an opportunity to bring in the dreg, assemble it in a place and sell it as raw materials to some of the businesses mentioned above. Part of the dreg can be sold to bakeries, to urban farms to make compost, off-shore fish farms and for wastewater treatment.
#
# ***The missing piece of information that we need is how many craft breweries are there in a given city, say New York City.***

# %% [markdown]
# ### DESCRIPTION OF THE DATA
#
# The data we require is simple.
#
#     - How many craft breweries are operational in New York City?
#     - Which ones are the most popular?
#     - Which ones have on-site brewing facilities
#
# We can use the FourSquare API to gather all the breweries operating in New York City. Craft breweries are primarily located in Manhattan and Brooklyn, but we can expand it to all boroughs if required. Using this list of breweries along with their ratings, we can choose a smaller set of breweries to launch a pilot to evaluate the business. The FourSquare might not be able to answer the third question, for which we might need a beer or two from the place of interest. The data on a map should help us locate a few places of interest where we can have our dreg warehouse in or close to New York City.

# %% [markdown]
# Reference Link: https://modernfarmer.com/2015/08/recycled-brewery-waste/

# %% [markdown]
# ### METHODOLOGY
#
# We use the FourSquare API which provides the option to list out all venues in a particular category. Each category has a specific ID in the FourSquare API using which we can find out how many venues of interest are there in a particular city or neighborhood.
#
# For this particular problem, we need to get the category ID for breweries from the FourSquare developer site.
#
# The FourSquare developer website is: https://developer.foursquare.com/docs/build-with-foursquare/categories/
#
# From here, we get the category ID for breweries: 50327c8591d4c4b30a586d5d
#
#
# Using this category ID, we then list out all breweries in an area of interest using the following steps:
#
#      1)For the above business application, we will be looking at all NYC boroughs.
#
#      2)We then extract the list of all breweries along with their ratings, if available.
#
#      3)We then choose the 3 or 5 top rated venues to organize a field visit, get a few questions answered and guzzle down a few beers
#
# Lets begin.

# %% [markdown]
#     1) Importing all required packages

# %%
import requests
import pandas as pd 
import numpy as np 
import random 

from geopy.geocoders import Nominatim 
from IPython.display import Image 
from IPython.core.display import HTML 
    
import json 
from pandas.io.json import json_normalize

import folium

# %% [markdown]
#     2) Setting up credentials for accessing the FourSquare API

# %%
CLIENT_ID = 'K0GYSKKQI0BC1RHBTXDSR0QWWVVDQYABARNBOYRTITACST2T' # your Foursquare ID
CLIENT_SECRET = 'C2P5LP0OAC0HU3QCKYSYYHW15S4OSHAUUMZT3WFEZ1PLV1BQ' # your Foursquare Secret
ACCESS_TOKEN = 'YYGLNU1W13OWG1V10JLLNOEKRUQM1KGDX3ZTRMO5KZQ5RPYB' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 10000
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: K0GYSKKQI0BC1RHBTXDSR0QWWVVDQYABARNBOYRTITACST2T
# CLIENT_SECRET:C2P5LP0OAC0HU3QCKYSYYHW15S4OSHAUUMZT3WFEZ1PLV1BQ

# %% [markdown]
#     3) Using the GeoLocator from Lab Exercises of Week 2 to get the co-ordinates of interest for New York City

# %%
address = '20 W 34th St, New York'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.65774729310345 -74.00725812068966

# %% [markdown]
#     4) Using the Category ID of Breweries, we get a list of all breweries in NYC

# %%
radius = 100000 #Going big to get as many as breweries as possible
brewery_Category_id = '50327c8591d4c4b30a586d5d'

brewery_url ='https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&categoryId={}&radius={}&limit={}'.format(
            CLIENT_ID,
            CLIENT_SECRET,
            latitude,
            longitude,
            ACCESS_TOKEN,
            VERSION,
            brewery_Category_id ,
            radius,
            LIMIT
            )

# %% [markdown]
# **Sending the GET Request and getting all the results**

# %%
results = requests.get(brewery_url).json()['response']
results
# Out:
# {'venues': [{'id': '5c6f5ada835c9a0039edf02c',
#    'name': 'Big Alice Barrel Room',
#    'location': {'address': '52 34th St',
#     'crossStreet': '2nd Ave',
#     'lat': 40.6574153788505,
#     'lng': -74.00696695747743,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.6574153788505,
#       'lng': -74.00696695747743}],
#     'distance': 44,
#     'postalCode': '11232',
#     'cc': 'US',
#     'neighborhood': 'Greenwood Heights',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['52 34th St (2nd Ave)',
#      'Brooklyn, NY 11232',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2477717',
#     'url': 'https://www.seamless.com/menu/big-alice-barrel-room-52-34th-street-brooklyn/2477717?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2477717',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5151c128e4b026975853f870',
#    'name': 'The Bronx Brewery',
#    'location': {'address': '856 E 136th St',
#     'crossStreet': 'between Willow Ave and Walnut Ave',
#     'lat': 40.80177432001329,
#     'lng': -73.91029715538025,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.80177432001329,
#       'lng': -73.91029715538025},
#      {'label': 'entrance', 'lat': 40.801998, 'lng': -73.910504}],
#     'distance': 17998,
#     'postalCode': '10454',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['856 E 136th St (between Willow Ave and Walnut Ave)',
#      'Bronx, NY 10454',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2039435',
#     'url': 'https://www.seamless.com/menu/the-bronx-brewery-856-e-136th-st-new-york/2039435?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2039435',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'venuePage': {'id': '140525663'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5e1e2003b57bd10008a2e101',
#    'name': 'Dockside Brewery',
#    'location': {'address': '40 Bridgeport Ave',
#     'lat': 41.2003375,
#     'lng': -73.10728759999999,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 41.2003375,
#       'lng': -73.10728759999999}],
#     'distance': 96835,
#     'postalCode': '06460',
#     'cc': 'US',
#     'city': 'Milford',
#     'state': 'CT',
#     'country': 'United States',
#     'formattedAddress': ['40 Bridgeport Ave',
#      'Milford, CT 06460',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2269810',
#     'url': 'https://www.grubhub.com/restaurant/dockside-brewery-40-bridgeport-avenue-milford/2269810?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2269810',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '572e1b2dcd10a820394a507b',
#    'name': 'Twin Elephant Brewing Company',
#    'location': {'lat': 40.72923819029399,
#     'lng': -74.38035333271759,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.72923819029399,
#       'lng': -74.38035333271759}],
#     'distance': 32480,
#     'postalCode': '07928',
#     'cc': 'US',
#     'city': 'Chatham Township',
#     'state': 'NJ',
#     'country': 'United States',
#     'formattedAddress': ['Chatham Township, NJ 07928', 'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '588fc9eed8f3e90ab908bc48',
#    'name': 'Hudson Valley Brewery',
#    'location': {'address': '7 E Main St',
#     'lat': 41.50154311094066,
#     'lng': -73.96299263866487,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 41.50154311094066,
#       'lng': -73.96299263866487},
#      {'label': 'entrance', 'lat': 41.501557, 'lng': -73.963205}],
#     'distance': 94003,
#     'postalCode': '12508',
#     'cc': 'US',
#     'city': 'Beacon',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['7 E Main St', 'Beacon, NY 12508', 'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '57eaf6a7498ee4d106a06ebf',
#    'name': 'Evil Twin Brewing NYC',
#    'location': {'address': '1616 George St',
#     'crossStreet': 'Wyckoff Ave.',
#     'lat': 40.696225281781494,
#     'lng': -73.90422463417052,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.696225281781494,
#       'lng': -73.90422463417052}],
#     'distance': 9695,
#     'postalCode': '11385',
#     'cc': 'US',
#     'city': 'Ridgewood',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1616 George St (Wyckoff Ave.)',
#      'Ridgewood, NY 11385',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2045157',
#     'url': 'https://www.seamless.com/menu/evil-twin-brewing-nyc-1616-george-st-ridgewood/2045157?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2045157',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '60303c4749e1267fe66b53ff',
#    'name': 'TALEA Beer Co',
#    'location': {'address': '87 Richardson St',
#     'crossStreet': 'Leonard St',
#     'lat': 40.718573,
#     'lng': -73.948276,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.718573,
#       'lng': -73.948276}],
#     'distance': 8404,
#     'postalCode': '11211',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['87 Richardson St (Leonard St)',
#      'Brooklyn, NY 11211',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '57a52544498e70074cf7a79b',
#    'name': 'Ship Bottom Brewery',
#    'location': {'address': '830 N Bay Avenue Store #23',
#     'lat': 39.56941682974368,
#     'lng': -74.23678667679498,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 39.56941682974368,
#       'lng': -74.23678667679498}],
#     'distance': 122717,
#     'postalCode': '08008',
#     'cc': 'US',
#     'city': 'Beach Haven',
#     'state': 'NJ',
#     'country': 'United States',
#     'formattedAddress': ['830 N Bay Avenue Store #23',
#      'Beach Haven, NJ 08008',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '56f6cd56cd102dca40d553c9',
#    'name': 'Kings County Brewers Collective',
#    'location': {'address': '381 Troutman St',
#     'lat': 40.70597434893818,
#     'lng': -73.92348707575466,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.70597434893818,
#       'lng': -73.92348707575466},
#      {'label': 'entrance', 'lat': 40.705993, 'lng': -73.923572}],
#     'distance': 8878,
#     'postalCode': '11237',
#     'cc': 'US',
#     'neighborhood': 'Bushwick',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['381 Troutman St',
#      'Brooklyn, NY 11237',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2478522',
#     'url': 'https://www.seamless.com/menu/kings-county-brewers-collective-381-troutman-street-brooklyn/2478522?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2478522',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5ee52222830eaa0008a81c31',
#    'name': 'The Keg & Lantern Brewing Company',
#    'location': {'address': '158 Beard St',
#     'crossStreet': 'Van Brunt St',
#     'lat': 40.67551,
#     'lng': -74.015746,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.67551,
#       'lng': -74.015746}],
#     'distance': 2103,
#     'postalCode': '11231',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['158 Beard St (Van Brunt St)',
#      'Brooklyn, NY 11231',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2304967',
#     'url': 'https://www.seamless.com/menu/keg--lantern-brewing-158-beard-st-brooklyn/2304967?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2304967',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '60bba5337f3f8e10f8ba498f',
#    'name': 'Long Island Farm Brewery',
#    'location': {'address': '663 Wading River Rd',
#     'lat': 40.855792,
#     'lng': -72.816329,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.855792,
#       'lng': -72.816329}],
#     'distance': 102812,
#     'postalCode': '11949',
#     'cc': 'US',
#     'city': 'Manorville',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['663 Wading River Rd',
#      'Manorville, NY 11949',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '58333baf88641b2f6bc26878',
#    'name': "K & D's Brewhouse",
#    'location': {'lat': 41.4611720939688,
#     'lng': -74.40310251684417,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 41.4611720939688,
#       'lng': -74.40310251684417}],
#     'distance': 95408,
#     'cc': 'US',
#     'city': 'Middletown',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['Middletown, NY', 'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5e7770833fe81d0008fe8d2c',
#    'name': 'Drowned Lands Brewery',
#    'location': {'address': '251 State School Rd',
#     'lat': 41.280006408691406,
#     'lng': -74.30646514892578,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 41.280006408691406,
#       'lng': -74.30646514892578}],
#     'distance': 73693,
#     'postalCode': '10990',
#     'cc': 'US',
#     'city': 'Warwick',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['251 State School Rd',
#      'Warwick, NY 10990',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5ec96cb42db3b500089448f9',
#    'name': 'Tin Barn Brewing',
#    'location': {'address': '62 Kings Highway Byp',
#     'lat': 41.318154,
#     'lng': -74.284447,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 41.318154,
#       'lng': -74.284447}],
#     'distance': 77117,
#     'postalCode': '10918',
#     'cc': 'US',
#     'city': 'Chester',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['62 Kings Highway Byp',
#      'Chester, NY 10918',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '60f723b5d509f33db08d0b04',
#    'name': 'Non Sequitur Beer Project',
#    'location': {'address': '8 Wilson Ave',
#     'lat': 40.70356207038148,
#     'lng': -73.93100917339325,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.70356207038148,
#       'lng': -73.93100917339325}],
#     'distance': 8212,
#     'postalCode': '11237',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['8 Wilson Ave',
#      'Brooklyn, NY 11237',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '60b2bddd4750db5eccabd1ae',
#    'name': 'Evil Twin Brewing NYC',
#    'location': {'address': '43 Main St',
#     'lat': 40.702965,
#     'lng': -73.9906,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.702965,
#       'lng': -73.9906}],
#     'distance': 5226,
#     'postalCode': '11201',
#     'cc': 'US',
#     'neighborhood': 'DUMBO',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['43 Main St', 'Brooklyn, NY 11201', 'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5ed3fb92cdc1e20008b35eea',
#    'name': 'Strong Rope Brewery',
#    'location': {'address': '185 Van Dyke St',
#     'lat': 40.677204433890786,
#     'lng': -74.01877105236053,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.677204433890786,
#       'lng': -74.01877105236053}],
#     'distance': 2374,
#     'postalCode': '11231',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['185 Van Dyke St',
#      'Brooklyn, NY 11231',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5fadb74076ca835ffbe52d60',
#    'name': 'Alewife Brewing',
#    'location': {'address': '41-11',
#     'crossStreet': '39th Street',
#     'lat': 40.746948,
#     'lng': -73.925321,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.746948,
#       'lng': -73.925321}],
#     'distance': 12100,
#     'postalCode': '11104',
#     'cc': 'US',
#     'city': 'Sunnyside',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['41-11 (39th Street)',
#      'Sunnyside, NY 11104',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5cf7c7370d173f002c396300',
#    'name': 'Sand City South',
#    'location': {'address': '150 S Wellwood Ave',
#     'crossStreet': 'W Hoffman Ave',
#     'lat': 40.68645095825195,
#     'lng': -73.37240600585938,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.68645095825195,
#       'lng': -73.37240600585938}],
#     'distance': 53695,
#     'postalCode': '11757',
#     'cc': 'US',
#     'city': 'Lindenhurst',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['150 S Wellwood Ave (W Hoffman Ave)',
#      'Lindenhurst, NY 11757',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5956d1ae6fd626672c705a01',
#    'name': 'Circa Brewing Co',
#    'location': {'address': '141 Lawrence St',
#     'crossStreet': 'btwn Willoughby St & Fulton Mall',
#     'lat': 40.691684974740014,
#     'lng': -73.98621812506313,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.691684974740014,
#       'lng': -73.98621812506313}],
#     'distance': 4174,
#     'postalCode': '11201',
#     'cc': 'US',
#     'neighborhood': 'Downtown Brooklyn',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['141 Lawrence St (btwn Willoughby St & Fulton Mall)',
#      'Brooklyn, NY 11201',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1179353',
#     'url': 'https://www.seamless.com/menu/circa-brewing-co-141-lawrence-st-brooklyn/1179353?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1179353',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5dfacb394355ad0008d1622a',
#    'name': 'Equilibrium Taproom',
#    'location': {'address': '2-8 South Street',
#     'lat': 41.444838,
#     'lng': -74.419916,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 41.444838,
#       'lng': -74.419916}],
#     'distance': 94217,
#     'postalCode': '10940',
#     'cc': 'US',
#     'city': 'Middletown',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['2-8 South Street',
#      'Middletown, NY 10940',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2423653',
#     'url': 'https://www.grubhub.com/restaurant/equilibrium-bonfire-2-south-st-middletown/2423653?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2423653',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5fa70b4788394a091aa06512',
#    'name': 'Other Half Brewing',
#    'location': {'address': '34 River St',
#     'crossStreet': 'at S 1st St',
#     'lat': 40.715886,
#     'lng': -73.966964,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.715886,
#       'lng': -73.966964}],
#     'distance': 7311,
#     'postalCode': '11222',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['34 River St (at S 1st St)',
#      'Brooklyn, NY 11222',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5e23b9ff6eaec100081d9071',
#    'name': 'Finback Brewery',
#    'location': {'address': '545 President St',
#     'lat': 40.677513122558594,
#     'lng': -73.9847412109375,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.677513122558594,
#       'lng': -73.9847412109375}],
#     'distance': 2907,
#     'postalCode': '11215',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['545 President St',
#      'Brooklyn, NY 11215',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5d1e7ebfd29cbb0023e08cc7',
#    'name': 'Greenpoint Beer and Ale Co.',
#    'location': {'address': '1150 Manhattan Ave',
#     'lat': 40.737669,
#     'lng': -73.955158,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.737669,
#       'lng': -73.955158}],
#     'distance': 9924,
#     'postalCode': '11222',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1150 Manhattan Ave',
#      'Brooklyn, NY 11222',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5b65b21b1c0b34002b1183de',
#    'name': 'Montclair Brewery',
#    'location': {'address': '101 Walnut Street',
#     'lat': 40.81702815045148,
#     'lng': -74.2110779989139,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.81702815045148,
#       'lng': -74.2110779989139}],
#     'distance': 24696,
#     'postalCode': '07042',
#     'cc': 'US',
#     'city': 'Montclair',
#     'state': 'NJ',
#     'country': 'United States',
#     'formattedAddress': ['101 Walnut Street',
#      'Montclair, NJ 07042',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '4bccbb8a937ca59377a9ab92',
#    'name': 'Anheuser Busch',
#    'location': {'lat': 40.69438181580483,
#     'lng': -74.18940516084962,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.69438181580483,
#       'lng': -74.18940516084962}],
#     'distance': 15909,
#     'postalCode': '07114',
#     'cc': 'US',
#     'city': 'Newark',
#     'state': 'NJ',
#     'country': 'United States',
#     'formattedAddress': ['Newark, NJ 07114', 'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '59ebbf3e356b491e43e832b9',
#    'name': 'River Outpost Brewing Company',
#    'location': {'address': '5 John Walsh Blvd',
#     'lat': 41.27586599157626,
#     'lng': -73.9432052248499,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 41.27586599157626,
#       'lng': -73.9432052248499}],
#     'distance': 69018,
#     'postalCode': '10566',
#     'cc': 'US',
#     'city': 'Peekskill',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['5 John Walsh Blvd',
#      'Peekskill, NY 10566',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '4f68de6bd5fbee32e5f4f3a5',
#    'name': 'SingleCut Beersmiths',
#    'location': {'address': '19-33 37th St',
#     'crossStreet': 'btwn 19th & 20th Ave',
#     'lat': 40.778386547058325,
#     'lng': -73.9019024216154,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.778386547058325,
#       'lng': -73.9019024216154}],
#     'distance': 16104,
#     'postalCode': '11105',
#     'cc': 'US',
#     'city': 'Astoria',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['19-33 37th St (btwn 19th & 20th Ave)',
#      'Astoria, NY 11105',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '1101487',
#     'url': 'https://www.seamless.com/menu/singlecut-beersmiths-1933-37th-st-astoria/1101487?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1101487',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'venuePage': {'id': '42728420'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '4b1883b5f964a520b6d323e3',
#    'name': 'Keg & Lantern Brewing Company',
#    'location': {'address': '97 Nassau Ave',
#     'crossStreet': 'btwn Manhattan & Leonard',
#     'lat': 40.72392428315277,
#     'lng': -73.95039223578604,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.72392428315277,
#       'lng': -73.95039223578604}],
#     'distance': 8792,
#     'postalCode': '11222',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['97 Nassau Ave (btwn Manhattan & Leonard)',
#      'Brooklyn, NY 11222',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11b941735',
#      'name': 'Pub',
#      'pluralName': 'Pubs',
#      'shortName': 'Pub',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '371420',
#     'url': 'https://www.seamless.com/menu/keg--lantern-brewing-company-97-nassau-ave-brooklyn/371420?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=371420',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'venuePage': {'id': '79422107'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '52eab90a498ee70cbe1ee103',
#    'name': 'Other Half Brewing Company',
#    'location': {'address': '195 Centre St',
#     'crossStreet': 'Smith & Court St',
#     'lat': 40.673789976521334,
#     'lng': -73.99913388740788,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.673789976521334,
#       'lng': -73.99913388740788},
#      {'label': 'entrance', 'lat': 40.673761, 'lng': -73.999168}],
#     'distance': 1913,
#     'postalCode': '11231',
#     'cc': 'US',
#     'neighborhood': 'Carroll Gardens',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['195 Centre St (Smith & Court St)',
#      'Brooklyn, NY 11231',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '563078020'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '50244fd4e4b065daa53e03b3',
#    'name': 'Rockaway Brewing Co.',
#    'location': {'address': '46-01 5th St',
#     'crossStreet': '46th Avenue',
#     'lat': 40.747336483161995,
#     'lng': -73.95484307605413,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.747336483161995,
#       'lng': -73.95484307605413}],
#     'distance': 10909,
#     'postalCode': '11101',
#     'cc': 'US',
#     'city': 'Queens',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['46-01 5th St (46th Avenue)',
#      'Long Island City, NY 11101',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '90538019'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '57376e4b498e7ef603e18c98',
#    'name': 'Folksbier',
#    'location': {'address': '101 Luquer St',
#     'lat': 40.677990990762666,
#     'lng': -74.00154533221303,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.677990990762666,
#       'lng': -74.00154533221303},
#      {'label': 'entrance', 'lat': 40.678006, 'lng': -74.001287}],
#     'distance': 2304,
#     'postalCode': '11231',
#     'cc': 'US',
#     'neighborhood': 'Carroll Gardens',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['101 Luquer St',
#      'Brooklyn, NY 11231',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2106892',
#     'url': 'https://www.seamless.com/menu/folksbier-brauerei-101-luquer-st-brooklyn/2106892?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2106892',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5414d0a6498ea3d31a3c64cf',
#    'name': 'Threes Brewing',
#    'location': {'address': '333 Douglass St',
#     'crossStreet': 'at 4th Ave',
#     'lat': 40.67979901271337,
#     'lng': -73.98215935484912,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.67979901271337,
#       'lng': -73.98215935484912}],
#     'distance': 3242,
#     'postalCode': '11217',
#     'cc': 'US',
#     'neighborhood': 'Gowanus',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['333 Douglass St (at 4th Ave)',
#      'Brooklyn, NY 11217',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '95760005'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5589a67e498ea3b4d67ffbd9',
#    'name': 'Coney Island Brewing Co.',
#    'location': {'address': '1904 Surf Ave',
#     'lat': 40.57518859380483,
#     'lng': -73.98399145930985,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.57518859380483,
#       'lng': -73.98399145930985}],
#     'distance': 9398,
#     'postalCode': '11224',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1904 Surf Ave',
#      'Brooklyn, NY 11224',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '4daa325543a1128196f2ecc2',
#    'name': 'Great South Bay Brewery',
#    'location': {'address': '25 Drexel Dr',
#     'crossStreet': 'at Fifth Ave.',
#     'lat': 40.76085224107264,
#     'lng': -73.26345933967026,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.76085224107264,
#       'lng': -73.26345933967026}],
#     'distance': 63804,
#     'postalCode': '11706',
#     'cc': 'US',
#     'city': 'Bay Shore',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['25 Drexel Dr (at Fifth Ave.)',
#      'Bay Shore, NY 11706',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5d0408fc491be7002ca2b754',
#    'name': 'ICONYC Brewery',
#    'location': {'address': '43-63 11th St',
#     'crossStreet': '12th St',
#     'lat': 40.750148,
#     'lng': -73.948649,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.750148,
#       'lng': -73.948649}],
#     'distance': 11413,
#     'postalCode': '11101',
#     'cc': 'US',
#     'city': 'Long Island City',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['43-63 11th St (12th St)',
#      'Long Island City, NY 11101',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5c0b06e4898bdc002c7fdb9e',
#    'name': 'Wild East Brewing Co.',
#    'location': {'address': '623 Sackett St',
#     'crossStreet': 'btwn Third & Forth Ave',
#     'lat': 40.678609,
#     'lng': -73.98341500000001,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.678609,
#       'lng': -73.98341500000001}],
#     'distance': 3073,
#     'postalCode': '11217',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['623 Sackett St (btwn Third & Forth Ave)',
#      'Brooklyn, NY 11217',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '4ae31336f964a5204a9021e3',
#    'name': 'Captain Lawrence Brewing Company',
#    'location': {'address': '444 Saw Mill River Rd',
#     'crossStreet': 'at Hunter Ln.',
#     'lat': 41.070412811921905,
#     'lng': -73.81370056417396,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 41.070412811921905,
#       'lng': -73.81370056417396}],
#     'distance': 48741,
#     'postalCode': '10523',
#     'cc': 'US',
#     'city': 'Elmsford',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['444 Saw Mill River Rd (at Hunter Ln.)',
#      'Elmsford, NY 10523',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '33657123'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5a455ff1b8fd9d266f246125',
#    'name': 'Grimm Artisanal Ales',
#    'location': {'address': '990 Metropolitan Ave',
#     'crossStreet': 'btwn Catherine St & Morgan Ave',
#     'lat': 40.71449430936535,
#     'lng': -73.93642240138722,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.71449430936535,
#       'lng': -73.93642240138722}],
#     'distance': 8698,
#     'postalCode': '11211',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['990 Metropolitan Ave (btwn Catherine St & Morgan Ave)',
#      'Brooklyn, NY 11211',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2033921',
#     'url': 'https://www.seamless.com/menu/grimm-artisanal-ales-990-metropolitan-ave-brooklyn/2033921?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2033921',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'venuePage': {'id': '560576785'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '502f02a7e4b05159d4f3f24d',
#    'name': 'The Malt House',
#    'location': {'address': '206 Thompson St',
#     'crossStreet': 'btwn 3rd St & Bleecker St',
#     'lat': 40.72863,
#     'lng': -73.99938,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.72863,
#       'lng': -73.99938}],
#     'distance': 7918,
#     'postalCode': '10012',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['206 Thompson St (btwn 3rd St & Bleecker St)',
#      'New York, NY 10012',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2091547',
#     'url': 'https://www.seamless.com/menu/the-malt-house-greenwich-village-206-thompson-street-new-york/2091547?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2091547',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'venuePage': {'id': '48888900'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '59713095dee77066f35b557d',
#    'name': 'Randolph Beer',
#    'location': {'address': '77 Sands St',
#     'crossStreet': 'Jay St',
#     'lat': 40.70054204495188,
#     'lng': -73.98776909606464,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.70054204495188,
#       'lng': -73.98776909606464}],
#     'distance': 5039,
#     'postalCode': '11201',
#     'cc': 'US',
#     'neighborhood': 'Downtown Brooklyn',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['77 Sands St (Jay St)',
#      'New York, NY 11201',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2202308',
#     'url': 'https://www.seamless.com/menu/randolph-beer-dumbo-82-prospect-st-brooklyn/2202308?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2202308',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '580bbe6c38fa27d5b5a442cc',
#    'name': 'Fifth Hammer Brewing Company',
#    'location': {'address': '10-28 46th Ave',
#     'lat': 40.74655304120232,
#     'lng': -73.95143837388332,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.74655304120232,
#       'lng': -73.95143837388332}],
#     'distance': 10950,
#     'postalCode': '11101',
#     'cc': 'US',
#     'neighborhood': 'Hunters Point',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['10-28 46th Ave',
#      'New York, NY 11101',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '3fd66200f964a5205deb1ee3',
#    'name': 'Brooklyn Brewery',
#    'location': {'address': '79 N 11th St',
#     'crossStreet': 'at Wythe Ave',
#     'lat': 40.7217061985696,
#     'lng': -73.95773446732501,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.7217061985696,
#       'lng': -73.95773446732501},
#      {'label': 'entrance', 'lat': 40.721569, 'lng': -73.957622}],
#     'distance': 8256,
#     'postalCode': '11249',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['79 N 11th St (at Wythe Ave)',
#      'Brooklyn, NY 11249',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2290044',
#     'url': 'https://www.seamless.com/menu/brooklyn-brewery-79-n-11th-st-brooklyn/2290044?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2290044',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'venuePage': {'id': '35307444'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5538ff3c498e27fbb347d2ff',
#    'name': 'Brix City Brewing',
#    'location': {'address': '4 Alsan Way',
#     'lat': 40.85641110404696,
#     'lng': -74.04324540111814,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.85641110404696,
#       'lng': -74.04324540111814},
#      {'label': 'entrance', 'lat': 40.85635, 'lng': -74.043124}],
#     'distance': 22322,
#     'postalCode': '07643',
#     'cc': 'US',
#     'city': 'Little Ferry',
#     'state': 'NJ',
#     'country': 'United States',
#     'formattedAddress': ['4 Alsan Way',
#      'Little Ferry, NJ 07643',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5e88c7acb223d800080dce56',
#    'name': 'Torch & Crown Brewing Company',
#    'location': {'address': '12 Vandam St',
#     'lat': 40.726314,
#     'lng': -74.004208,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.726314,
#       'lng': -74.004208}],
#     'distance': 7637,
#     'postalCode': '10013',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['12 Vandam St',
#      'New York, NY 10013',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2443332',
#     'url': 'https://www.seamless.com/menu/torch-and-crown-brewery--restaurant-12-vandam-st-new-york/2443332?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2443332',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '5aa8657369e77b5f8bd11618',
#    'name': 'Queens Brewery',
#    'location': {'address': '1539 Covert St',
#     'lat': 40.69507055145107,
#     'lng': -73.90386715385252,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.69507055145107,
#       'lng': -73.90386715385252}],
#     'distance': 9667,
#     'postalCode': '11385',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1539 Covert St',
#      'New York, NY 11385',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '2479259',
#     'url': 'https://www.seamless.com/menu/queens-brewery-1539-covert-street-ridgewood/2479259?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2479259',
#     'provider': {'name': 'seamless',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_seamless_20180129.png'}}},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '576edb14498e125c56070307',
#    'name': 'Rockaway Brewing Co.',
#    'location': {'address': '415 Beach 72nd St',
#     'crossStreet': 'Amstel Blvd',
#     'lat': 40.59306900566265,
#     'lng': -73.80085203416041,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.59306900566265,
#       'lng': -73.80085203416041}],
#     'distance': 18866,
#     'postalCode': '11692',
#     'cc': 'US',
#     'city': 'Far Rockaway',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['415 Beach 72nd St (Amstel Blvd)',
#      'Far Rockaway, NY 11692',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '4b43c15bf964a520a3e825e3',
#    'name': 'Weyerbacher Brewing Co\u200empany',
#    'location': {'address': '905 Line St',
#     'crossStreet': 'btwn Packer & Iron St',
#     'lat': 40.67347825547521,
#     'lng': -75.22624899364956,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.67347825547521,
#       'lng': -75.22624899364956},
#      {'label': 'entrance', 'lat': 40.673199, 'lng': -75.22549}],
#     'distance': 102943,
#     'postalCode': '18042',
#     'cc': 'US',
#     'city': 'Easton',
#     'state': 'PA',
#     'country': 'United States',
#     'formattedAddress': ['905 Line St (btwn Packer & Iron St)',
#      'Easton, PA 18042',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '70188748'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '4ad5f46df964a5202a0421e3',
#    'name': 'Triumph Brewing',
#    'location': {'address': '400 Union Square Dr',
#     'crossStreet': 'at Union Square',
#     'lat': 40.365228206880815,
#     'lng': -74.95388804716158,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.365228206880815,
#       'lng': -74.95388804716158},
#      {'label': 'entrance', 'lat': 40.365403, 'lng': -74.95443}],
#     'distance': 86480,
#     'postalCode': '18938',
#     'cc': 'US',
#     'city': 'New Hope',
#     'state': 'PA',
#     'country': 'United States',
#     'formattedAddress': ['400 Union Square Dr (at Union Square)',
#      'New Hope, PA 18938',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '35391385'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False},
#   {'id': '55046643498e89d9f4bf1418',
#    'name': 'Departed Soles Brewing Co.',
#    'location': {'address': '150 Bay Street, Commercial Side, Suite 2a',
#     'crossStreet': 'Marin Boulevard',
#     'lat': 40.72065986602712,
#     'lng': -74.04028695893082,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.72065986602712,
#       'lng': -74.04028695893082}],
#     'distance': 7537,
#     'postalCode': '07302',
#     'cc': 'US',
#     'city': 'Jersey City',
#     'state': 'NJ',
#     'country': 'United States',
#     'formattedAddress': ['150 Bay Street, Commercial Side, Suite 2a (Marin Boulevard)',
#      'Jersey City, NJ 07302',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '127032515'},
#    'referralId': 'v-1628443191',
#    'hasPerk': False}],
#  'confident': False}

# %% [markdown]
# **Get relevant part of JSON and transform it into a pandas dataframe**

# %%
# assign relevant part of JSON to venues
venues = results["venues"]


# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe
# Out:
# <ipython-input-6-79968ec94a71>:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                           id                               name  \
# 0   5c6f5ada835c9a0039edf02c              Big Alice Barrel Room
# 1   5151c128e4b026975853f870                  The Bronx Brewery
# 2   5e1e2003b57bd10008a2e101                   Dockside Brewery
# 3   572e1b2dcd10a820394a507b      Twin Elephant Brewing Company
# 4   588fc9eed8f3e90ab908bc48              Hudson Valley Brewery
# 5   57eaf6a7498ee4d106a06ebf              Evil Twin Brewing NYC
# 6   60303c4749e1267fe66b53ff                      TALEA Beer Co
# 7   57a52544498e70074cf7a79b                Ship Bottom Brewery
# 8   56f6cd56cd102dca40d553c9    Kings County Brewers Collective
# 9   5ee52222830eaa0008a81c31  The Keg & Lantern Brewing Company
# 10  60bba5337f3f8e10f8ba498f           Long Island Farm Brewery
# 11  58333baf88641b2f6bc26878                  K & D's Brewhouse
# 12  5e7770833fe81d0008fe8d2c              Drowned Lands Brewery
# 13  5ec96cb42db3b500089448f9                   Tin Barn Brewing
# 14  60f723b5d509f33db08d0b04          Non Sequitur Beer Project
# 15  60b2bddd4750db5eccabd1ae              Evil Twin Brewing NYC
# 16  5ed3fb92cdc1e20008b35eea                Strong Rope Brewery
# 17  5fadb74076ca835ffbe52d60                    Alewife Brewing
# 18  5cf7c7370d173f002c396300                    Sand City South
# 19  5956d1ae6fd626672c705a01                   Circa Brewing Co
# 20  5dfacb394355ad0008d1622a                Equilibrium Taproom
# 21  5fa70b4788394a091aa06512                 Other Half Brewing
# 22  5e23b9ff6eaec100081d9071                    Finback Brewery
# 23  5d1e7ebfd29cbb0023e08cc7        Greenpoint Beer and Ale Co.
# 24  5b65b21b1c0b34002b1183de                  Montclair Brewery
# 25  4bccbb8a937ca59377a9ab92                     Anheuser Busch
# 26  59ebbf3e356b491e43e832b9      River Outpost Brewing Company
# 27  4f68de6bd5fbee32e5f4f3a5               SingleCut Beersmiths
# 28  4b1883b5f964a520b6d323e3      Keg & Lantern Brewing Company
# 29  52eab90a498ee70cbe1ee103         Other Half Brewing Company
# 30  50244fd4e4b065daa53e03b3               Rockaway Brewing Co.
# 31  57376e4b498e7ef603e18c98                          Folksbier
# 32  5414d0a6498ea3d31a3c64cf                     Threes Brewing
# 33  5589a67e498ea3b4d67ffbd9           Coney Island Brewing Co.
# 34  4daa325543a1128196f2ecc2            Great South Bay Brewery
# 35  5d0408fc491be7002ca2b754                     ICONYC Brewery
# 36  5c0b06e4898bdc002c7fdb9e              Wild East Brewing Co.
# 37  4ae31336f964a5204a9021e3   Captain Lawrence Brewing Company
# 38  5a455ff1b8fd9d266f246125               Grimm Artisanal Ales
# 39  502f02a7e4b05159d4f3f24d                     The Malt House
# 40  59713095dee77066f35b557d                      Randolph Beer
# 41  580bbe6c38fa27d5b5a442cc       Fifth Hammer Brewing Company
# 42  3fd66200f964a5205deb1ee3                   Brooklyn Brewery
# 43  5538ff3c498e27fbb347d2ff                  Brix City Brewing
# 44  5e88c7acb223d800080dce56      Torch & Crown Brewing Company
# 45  5aa8657369e77b5f8bd11618                     Queens Brewery
# 46  576edb14498e125c56070307               Rockaway Brewing Co.
# 47  4b43c15bf964a520a3e825e3       Weyerbacher Brewing Co‎mpany
# 48  4ad5f46df964a5202a0421e3                    Triumph Brewing
# 49  55046643498e89d9f4bf1418         Departed Soles Brewing Co.
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 1   [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 2   [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 3   [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 4   [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 5   [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 6   [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 7   [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 8   [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 9   [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 10  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 11  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 12  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 13  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 14  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 15  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 16  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 17  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 18  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 19  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 20  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 21  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 22  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 23  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 24  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 25  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 26  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 27  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 28  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...  v-1628443191    False
# 29  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 30  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 31  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 32  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 33  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 34  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 35  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 36  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 37  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 38  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 39  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1628443191    False
# 40  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1628443191    False
# 41  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 42  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 43  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 44  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 45  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 46  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 47  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 48  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
# 49  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1628443191    False
#
#                              location.address  \
# 0                                  52 34th St
# 1                              856 E 136th St
# 2                           40 Bridgeport Ave
# 3                                         NaN
# 4                                 7 E Main St
# 5                              1616 George St
# 6                            87 Richardson St
# 7                  830 N Bay Avenue Store #23
# 8                             381 Troutman St
# 9                                158 Beard St
# 10                        663 Wading River Rd
# 11                                        NaN
# 12                        251 State School Rd
# 13                       62 Kings Highway Byp
# 14                               8 Wilson Ave
# 15                                 43 Main St
# 16                            185 Van Dyke St
# 17                                      41-11
# 18                         150 S Wellwood Ave
# 19                            141 Lawrence St
# 20                           2-8 South Street
# 21                                34 River St
# 22                           545 President St
# 23                         1150 Manhattan Ave
# 24                          101 Walnut Street
# 25                                        NaN
# 26                          5 John Walsh Blvd
# 27                              19-33 37th St
# 28                              97 Nassau Ave
# 29                              195 Centre St
# 30                               46-01 5th St
# 31                              101 Luquer St
# 32                            333 Douglass St
# 33                              1904 Surf Ave
# 34                               25 Drexel Dr
# 35                              43-63 11th St
# 36                             623 Sackett St
# 37                      444 Saw Mill River Rd
# 38                       990 Metropolitan Ave
# 39                            206 Thompson St
# 40                                77 Sands St
# 41                             10-28 46th Ave
# 42                               79 N 11th St
# 43                                4 Alsan Way
# 44                               12 Vandam St
# 45                             1539 Covert St
# 46                          415 Beach 72nd St
# 47                                905 Line St
# 48                        400 Union Square Dr
# 49  150 Bay Street, Commercial Side, Suite 2a
#
#                  location.crossStreet  location.lat  location.lng  \
# 0                             2nd Ave     40.657415    -74.006967
# 1   between Willow Ave and Walnut Ave     40.801774    -73.910297
# 2                                 NaN     41.200338    -73.107288
# 3                                 NaN     40.729238    -74.380353
# 4                                 NaN     41.501543    -73.962993
# 5                        Wyckoff Ave.     40.696225    -73.904225
# 6                          Leonard St     40.718573    -73.948276
# 7                                 NaN     39.569417    -74.236787
# 8                                 NaN     40.705974    -73.923487
# 9                        Van Brunt St     40.675510    -74.015746
# 10                                NaN     40.855792    -72.816329
# 11                                NaN     41.461172    -74.403103
# 12                                NaN     41.280006    -74.306465
# 13                                NaN     41.318154    -74.284447
# 14                                NaN     40.703562    -73.931009
# 15                                NaN     40.702965    -73.990600
# 16                                NaN     40.677204    -74.018771
# 17                        39th Street     40.746948    -73.925321
# 18                      W Hoffman Ave     40.686451    -73.372406
# 19   btwn Willoughby St & Fulton Mall     40.691685    -73.986218
# 20                                NaN     41.444838    -74.419916
# 21                        at S 1st St     40.715886    -73.966964
# 22                                NaN     40.677513    -73.984741
# 23                                NaN     40.737669    -73.955158
# 24                                NaN     40.817028    -74.211078
# 25                                NaN     40.694382    -74.189405
# 26                                NaN     41.275866    -73.943205
# 27               btwn 19th & 20th Ave     40.778387    -73.901902
# 28           btwn Manhattan & Leonard     40.723924    -73.950392
# 29                   Smith & Court St     40.673790    -73.999134
# 30                        46th Avenue     40.747336    -73.954843
# 31                                NaN     40.677991    -74.001545
# 32                         at 4th Ave     40.679799    -73.982159
# 33                                NaN     40.575189    -73.983991
# 34                      at Fifth Ave.     40.760852    -73.263459
# 35                            12th St     40.750148    -73.948649
# 36             btwn Third & Forth Ave     40.678609    -73.983415
# 37                      at Hunter Ln.     41.070413    -73.813701
# 38     btwn Catherine St & Morgan Ave     40.714494    -73.936422
# 39          btwn 3rd St & Bleecker St     40.728630    -73.999380
# 40                             Jay St     40.700542    -73.987769
# 41                                NaN     40.746553    -73.951438
# 42                       at Wythe Ave     40.721706    -73.957734
# 43                                NaN     40.856411    -74.043245
# 44                                NaN     40.726314    -74.004208
# 45                                NaN     40.695071    -73.903867
# 46                        Amstel Blvd     40.593069    -73.800852
# 47              btwn Packer & Iron St     40.673478    -75.226249
# 48                    at Union Square     40.365228    -74.953888
# 49                    Marin Boulevard     40.720660    -74.040287
#
#                               location.labeledLatLngs  ...  location.state  \
# 0   [{'label': 'display', 'lat': 40.6574153788505,...  ...              NY
# 1   [{'label': 'display', 'lat': 40.80177432001329...  ...              NY
# 2   [{'label': 'display', 'lat': 41.2003375, 'lng'...  ...              CT
# 3   [{'label': 'display', 'lat': 40.72923819029399...  ...              NJ
# 4   [{'label': 'display', 'lat': 41.50154311094066...  ...              NY
# 5   [{'label': 'display', 'lat': 40.69622528178149...  ...              NY
# 6   [{'label': 'display', 'lat': 40.718573, 'lng':...  ...              NY
# 7   [{'label': 'display', 'lat': 39.56941682974368...  ...              NJ
# 8   [{'label': 'display', 'lat': 40.70597434893818...  ...              NY
# 9   [{'label': 'display', 'lat': 40.67551, 'lng': ...  ...              NY
# 10  [{'label': 'display', 'lat': 40.855792, 'lng':...  ...              NY
# 11  [{'label': 'display', 'lat': 41.4611720939688,...  ...              NY
# 12  [{'label': 'display', 'lat': 41.28000640869140...  ...              NY
# 13  [{'label': 'display', 'lat': 41.318154, 'lng':...  ...              NY
# 14  [{'label': 'display', 'lat': 40.70356207038148...  ...              NY
# 15  [{'label': 'display', 'lat': 40.702965, 'lng':...  ...              NY
# 16  [{'label': 'display', 'lat': 40.67720443389078...  ...              NY
# 17  [{'label': 'display', 'lat': 40.746948, 'lng':...  ...              NY
# 18  [{'label': 'display', 'lat': 40.68645095825195...  ...              NY
# 19  [{'label': 'display', 'lat': 40.69168497474001...  ...              NY
# 20  [{'label': 'display', 'lat': 41.444838, 'lng':...  ...              NY
# 21  [{'label': 'display', 'lat': 40.715886, 'lng':...  ...              NY
# 22  [{'label': 'display', 'lat': 40.67751312255859...  ...              NY
# 23  [{'label': 'display', 'lat': 40.737669, 'lng':...  ...              NY
# 24  [{'label': 'display', 'lat': 40.81702815045148...  ...              NJ
# 25  [{'label': 'display', 'lat': 40.69438181580483...  ...              NJ
# 26  [{'label': 'display', 'lat': 41.27586599157626...  ...              NY
# 27  [{'label': 'display', 'lat': 40.77838654705832...  ...              NY
# 28  [{'label': 'display', 'lat': 40.72392428315277...  ...              NY
# 29  [{'label': 'display', 'lat': 40.67378997652133...  ...              NY
# 30  [{'label': 'display', 'lat': 40.74733648316199...  ...              NY
# 31  [{'label': 'display', 'lat': 40.67799099076266...  ...              NY
# 32  [{'label': 'display', 'lat': 40.67979901271337...  ...              NY
# 33  [{'label': 'display', 'lat': 40.57518859380483...  ...              NY
# 34  [{'label': 'display', 'lat': 40.76085224107264...  ...              NY
# 35  [{'label': 'display', 'lat': 40.750148, 'lng':...  ...              NY
# 36  [{'label': 'display', 'lat': 40.678609, 'lng':...  ...              NY
# 37  [{'label': 'display', 'lat': 41.07041281192190...  ...              NY
# 38  [{'label': 'display', 'lat': 40.71449430936535...  ...              NY
# 39  [{'label': 'display', 'lat': 40.72863, 'lng': ...  ...              NY
# 40  [{'label': 'display', 'lat': 40.70054204495188...  ...              NY
# 41  [{'label': 'display', 'lat': 40.74655304120232...  ...              NY
# 42  [{'label': 'display', 'lat': 40.7217061985696,...  ...              NY
# 43  [{'label': 'display', 'lat': 40.85641110404696...  ...              NJ
# 44  [{'label': 'display', 'lat': 40.726314, 'lng':...  ...              NY
# 45  [{'label': 'display', 'lat': 40.69507055145107...  ...              NY
# 46  [{'label': 'display', 'lat': 40.59306900566265...  ...              NY
# 47  [{'label': 'display', 'lat': 40.67347825547521...  ...              PA
# 48  [{'label': 'display', 'lat': 40.36522820688081...  ...              PA
# 49  [{'label': 'display', 'lat': 40.72065986602712...  ...              NJ
#
#    location.country                          location.formattedAddress  \
# 0     United States  [52 34th St (2nd Ave), Brooklyn, NY 11232, Uni...
# 1     United States  [856 E 136th St (between Willow Ave and Walnut...
# 2     United States  [40 Bridgeport Ave, Milford, CT 06460, United ...
# 3     United States        [Chatham Township, NJ 07928, United States]
# 4     United States     [7 E Main St, Beacon, NY 12508, United States]
# 5     United States  [1616 George St (Wyckoff Ave.), Ridgewood, NY ...
# 6     United States  [87 Richardson St (Leonard St), Brooklyn, NY 1...
# 7     United States  [830 N Bay Avenue Store #23, Beach Haven, NJ 0...
# 8     United States  [381 Troutman St, Brooklyn, NY 11237, United S...
# 9     United States  [158 Beard St (Van Brunt St), Brooklyn, NY 112...
# 10    United States  [663 Wading River Rd, Manorville, NY 11949, Un...
# 11    United States                    [Middletown, NY, United States]
# 12    United States  [251 State School Rd, Warwick, NY 10990, Unite...
# 13    United States  [62 Kings Highway Byp, Chester, NY 10918, Unit...
# 14    United States  [8 Wilson Ave, Brooklyn, NY 11237, United States]
# 15    United States    [43 Main St, Brooklyn, NY 11201, United States]
# 16    United States  [185 Van Dyke St, Brooklyn, NY 11231, United S...
# 17    United States  [41-11 (39th Street), Sunnyside, NY 11104, Uni...
# 18    United States  [150 S Wellwood Ave (W Hoffman Ave), Lindenhur...
# 19    United States  [141 Lawrence St (btwn Willoughby St & Fulton ...
# 20    United States  [2-8 South Street, Middletown, NY 10940, Unite...
# 21    United States  [34 River St (at S 1st St), Brooklyn, NY 11222...
# 22    United States  [545 President St, Brooklyn, NY 11215, United ...
# 23    United States  [1150 Manhattan Ave, Brooklyn, NY 11222, Unite...
# 24    United States  [101 Walnut Street, Montclair, NJ 07042, Unite...
# 25    United States                  [Newark, NJ 07114, United States]
# 26    United States  [5 John Walsh Blvd, Peekskill, NY 10566, Unite...
# 27    United States  [19-33 37th St (btwn 19th & 20th Ave), Astoria...
# 28    United States  [97 Nassau Ave (btwn Manhattan & Leonard), Bro...
# 29    United States  [195 Centre St (Smith & Court St), Brooklyn, N...
# 30    United States  [46-01 5th St (46th Avenue), Long Island City,...
# 31    United States  [101 Luquer St, Brooklyn, NY 11231, United Sta...
# 32    United States  [333 Douglass St (at 4th Ave), Brooklyn, NY 11...
# 33    United States  [1904 Surf Ave, Brooklyn, NY 11224, United Sta...
# 34    United States  [25 Drexel Dr (at Fifth Ave.), Bay Shore, NY 1...
# 35    United States  [43-63 11th St (12th St), Long Island City, NY...
# 36    United States  [623 Sackett St (btwn Third & Forth Ave), Broo...
# 37    United States  [444 Saw Mill River Rd (at Hunter Ln.), Elmsfo...
# 38    United States  [990 Metropolitan Ave (btwn Catherine St & Mor...
# 39    United States  [206 Thompson St (btwn 3rd St & Bleecker St), ...
# 40    United States  [77 Sands St (Jay St), New York, NY 11201, Uni...
# 41    United States  [10-28 46th Ave, New York, NY 11101, United St...
# 42    United States  [79 N 11th St (at Wythe Ave), Brooklyn, NY 112...
# 43    United States  [4 Alsan Way, Little Ferry, NJ 07643, United S...
# 44    United States  [12 Vandam St, New York, NY 10013, United States]
# 45    United States  [1539 Covert St, New York, NY 11385, United St...
# 46    United States  [415 Beach 72nd St (Amstel Blvd), Far Rockaway...
# 47    United States  [905 Line St (btwn Packer & Iron St), Easton, ...
# 48    United States  [400 Union Square Dr (at Union Square), New Ho...
# 49    United States  [150 Bay Street, Commercial Side, Suite 2a (Ma...
#
#    delivery.id                                       delivery.url  \
# 0      2477717  https://www.seamless.com/menu/big-alice-barrel...
# 1      2039435  https://www.seamless.com/menu/the-bronx-brewer...
# 2      2269810  https://www.grubhub.com/restaurant/dockside-br...
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# 5      2045157  https://www.seamless.com/menu/evil-twin-brewin...
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8      2478522  https://www.seamless.com/menu/kings-county-bre...
# 9      2304967  https://www.seamless.com/menu/keg--lantern-bre...
# 10         NaN                                                NaN
# 11         NaN                                                NaN
# 12         NaN                                                NaN
# 13         NaN                                                NaN
# 14         NaN                                                NaN
# 15         NaN                                                NaN
# 16         NaN                                                NaN
# 17         NaN                                                NaN
# 18         NaN                                                NaN
# 19     1179353  https://www.seamless.com/menu/circa-brewing-co...
# 20     2423653  https://www.grubhub.com/restaurant/equilibrium...
# 21         NaN                                                NaN
# 22         NaN                                                NaN
# 23         NaN                                                NaN
# 24         NaN                                                NaN
# 25         NaN                                                NaN
# 26         NaN                                                NaN
# 27     1101487  https://www.seamless.com/menu/singlecut-beersm...
# 28      371420  https://www.seamless.com/menu/keg--lantern-bre...
# 29         NaN                                                NaN
# 30         NaN                                                NaN
# 31     2106892  https://www.seamless.com/menu/folksbier-brauer...
# 32         NaN                                                NaN
# 33         NaN                                                NaN
# 34         NaN                                                NaN
# 35         NaN                                                NaN
# 36         NaN                                                NaN
# 37         NaN                                                NaN
# 38     2033921  https://www.seamless.com/menu/grimm-artisanal-...
# 39     2091547  https://www.seamless.com/menu/the-malt-house-g...
# 40     2202308  https://www.seamless.com/menu/randolph-beer-du...
# 41         NaN                                                NaN
# 42     2290044  https://www.seamless.com/menu/brooklyn-brewery...
# 43         NaN                                                NaN
# 44     2443332  https://www.seamless.com/menu/torch-and-crown-...
# 45     2479259  https://www.seamless.com/menu/queens-brewery-1...
# 46         NaN                                                NaN
# 47         NaN                                                NaN
# 48         NaN                                                NaN
# 49         NaN                                                NaN
#
#    delivery.provider.name             delivery.provider.icon.prefix  \
# 0                seamless  https://fastly.4sqi.net/img/general/cap/
# 1                seamless  https://fastly.4sqi.net/img/general/cap/
# 2                 grubhub  https://fastly.4sqi.net/img/general/cap/
# 3                     NaN                                       NaN
# 4                     NaN                                       NaN
# 5                seamless  https://fastly.4sqi.net/img/general/cap/
# 6                     NaN                                       NaN
# 7                     NaN                                       NaN
# 8                seamless  https://fastly.4sqi.net/img/general/cap/
# 9                seamless  https://fastly.4sqi.net/img/general/cap/
# 10                    NaN                                       NaN
# 11                    NaN                                       NaN
# 12                    NaN                                       NaN
# 13                    NaN                                       NaN
# 14                    NaN                                       NaN
# 15                    NaN                                       NaN
# 16                    NaN                                       NaN
# 17                    NaN                                       NaN
# 18                    NaN                                       NaN
# 19               seamless  https://fastly.4sqi.net/img/general/cap/
# 20                grubhub  https://fastly.4sqi.net/img/general/cap/
# 21                    NaN                                       NaN
# 22                    NaN                                       NaN
# 23                    NaN                                       NaN
# 24                    NaN                                       NaN
# 25                    NaN                                       NaN
# 26                    NaN                                       NaN
# 27               seamless  https://fastly.4sqi.net/img/general/cap/
# 28               seamless  https://fastly.4sqi.net/img/general/cap/
# 29                    NaN                                       NaN
# 30                    NaN                                       NaN
# 31               seamless  https://fastly.4sqi.net/img/general/cap/
# 32                    NaN                                       NaN
# 33                    NaN                                       NaN
# 34                    NaN                                       NaN
# 35                    NaN                                       NaN
# 36                    NaN                                       NaN
# 37                    NaN                                       NaN
# 38               seamless  https://fastly.4sqi.net/img/general/cap/
# 39               seamless  https://fastly.4sqi.net/img/general/cap/
# 40               seamless  https://fastly.4sqi.net/img/general/cap/
# 41                    NaN                                       NaN
# 42               seamless  https://fastly.4sqi.net/img/general/cap/
# 43                    NaN                                       NaN
# 44               seamless  https://fastly.4sqi.net/img/general/cap/
# 45               seamless  https://fastly.4sqi.net/img/general/cap/
# 46                    NaN                                       NaN
# 47                    NaN                                       NaN
# 48                    NaN                                       NaN
# 49                    NaN                                       NaN
#
#    delivery.provider.icon.sizes               delivery.provider.icon.name  \
# 0                      [40, 50]  /delivery_provider_seamless_20180129.png
# 1                      [40, 50]  /delivery_provider_seamless_20180129.png
# 2                      [40, 50]   /delivery_provider_grubhub_20180129.png
# 3                           NaN                                       NaN
# 4                           NaN                                       NaN
# 5                      [40, 50]  /delivery_provider_seamless_20180129.png
# 6                           NaN                                       NaN
# 7                           NaN                                       NaN
# 8                      [40, 50]  /delivery_provider_seamless_20180129.png
# 9                      [40, 50]  /delivery_provider_seamless_20180129.png
# 10                          NaN                                       NaN
# 11                          NaN                                       NaN
# 12                          NaN                                       NaN
# 13                          NaN                                       NaN
# 14                          NaN                                       NaN
# 15                          NaN                                       NaN
# 16                          NaN                                       NaN
# 17                          NaN                                       NaN
# 18                          NaN                                       NaN
# 19                     [40, 50]  /delivery_provider_seamless_20180129.png
# 20                     [40, 50]   /delivery_provider_grubhub_20180129.png
# 21                          NaN                                       NaN
# 22                          NaN                                       NaN
# 23                          NaN                                       NaN
# 24                          NaN                                       NaN
# 25                          NaN                                       NaN
# 26                          NaN                                       NaN
# 27                     [40, 50]  /delivery_provider_seamless_20180129.png
# 28                     [40, 50]  /delivery_provider_seamless_20180129.png
# 29                          NaN                                       NaN
# 30                          NaN                                       NaN
# 31                     [40, 50]  /delivery_provider_seamless_20180129.png
# 32                          NaN                                       NaN
# 33                          NaN                                       NaN
# 34                          NaN                                       NaN
# 35                          NaN                                       NaN
# 36                          NaN                                       NaN
# 37                          NaN                                       NaN
# 38                     [40, 50]  /delivery_provider_seamless_20180129.png
# 39                     [40, 50]  /delivery_provider_seamless_20180129.png
# 40                     [40, 50]  /delivery_provider_seamless_20180129.png
# 41                          NaN                                       NaN
# 42                     [40, 50]  /delivery_provider_seamless_20180129.png
# 43                          NaN                                       NaN
# 44                     [40, 50]  /delivery_provider_seamless_20180129.png
# 45                     [40, 50]  /delivery_provider_seamless_20180129.png
# 46                          NaN                                       NaN
# 47                          NaN                                       NaN
# 48                          NaN                                       NaN
# 49                          NaN                                       NaN
#
#    venuePage.id
# 0           NaN
# 1     140525663
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27     42728420
# 28     79422107
# 29    563078020
# 30     90538019
# 31          NaN
# 32     95760005
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37     33657123
# 38    560576785
# 39     48888900
# 40          NaN
# 41          NaN
# 42     35307444
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47     70188748
# 48     35391385
# 49    127032515
#
# [50 rows x 25 columns]

# %% [markdown]
# **Keeping only columns of interest**

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_cleaned = dataframe.loc[:, filtered_columns]

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_cleaned['categories'] = dataframe_cleaned.apply(get_category_type, axis=1)

# %%
dataframe_cleaned.columns = [column.split('.')[-1] for column in dataframe_cleaned.columns]

dataframe_cleaned
# Out:
#                                  name categories  \
# 0               Big Alice Barrel Room    Brewery
# 1                   The Bronx Brewery    Brewery
# 2                    Dockside Brewery    Brewery
# 3       Twin Elephant Brewing Company    Brewery
# 4               Hudson Valley Brewery    Brewery
# 5               Evil Twin Brewing NYC    Brewery
# 6                       TALEA Beer Co    Brewery
# 7                 Ship Bottom Brewery    Brewery
# 8     Kings County Brewers Collective    Brewery
# 9   The Keg & Lantern Brewing Company    Brewery
# 10           Long Island Farm Brewery    Brewery
# 11                  K & D's Brewhouse    Brewery
# 12              Drowned Lands Brewery    Brewery
# 13                   Tin Barn Brewing    Brewery
# 14          Non Sequitur Beer Project    Brewery
# 15              Evil Twin Brewing NYC    Brewery
# 16                Strong Rope Brewery    Brewery
# 17                    Alewife Brewing    Brewery
# 18                    Sand City South    Brewery
# 19                   Circa Brewing Co    Brewery
# 20                Equilibrium Taproom    Brewery
# 21                 Other Half Brewing    Brewery
# 22                    Finback Brewery    Brewery
# 23        Greenpoint Beer and Ale Co.    Brewery
# 24                  Montclair Brewery    Brewery
# 25                     Anheuser Busch    Brewery
# 26      River Outpost Brewing Company    Brewery
# 27               SingleCut Beersmiths    Brewery
# 28      Keg & Lantern Brewing Company        Pub
# 29         Other Half Brewing Company    Brewery
# 30               Rockaway Brewing Co.    Brewery
# 31                          Folksbier    Brewery
# 32                     Threes Brewing    Brewery
# 33           Coney Island Brewing Co.    Brewery
# 34            Great South Bay Brewery    Brewery
# 35                     ICONYC Brewery    Brewery
# 36              Wild East Brewing Co.    Brewery
# 37   Captain Lawrence Brewing Company    Brewery
# 38               Grimm Artisanal Ales    Brewery
# 39                     The Malt House        Bar
# 40                      Randolph Beer        Bar
# 41       Fifth Hammer Brewing Company    Brewery
# 42                   Brooklyn Brewery    Brewery
# 43                  Brix City Brewing    Brewery
# 44      Torch & Crown Brewing Company    Brewery
# 45                     Queens Brewery    Brewery
# 46               Rockaway Brewing Co.    Brewery
# 47       Weyerbacher Brewing Co‎mpany    Brewery
# 48                    Triumph Brewing    Brewery
# 49         Departed Soles Brewing Co.    Brewery
#
#                                       address  \
# 0                                  52 34th St
# 1                              856 E 136th St
# 2                           40 Bridgeport Ave
# 3                                         NaN
# 4                                 7 E Main St
# 5                              1616 George St
# 6                            87 Richardson St
# 7                  830 N Bay Avenue Store #23
# 8                             381 Troutman St
# 9                                158 Beard St
# 10                        663 Wading River Rd
# 11                                        NaN
# 12                        251 State School Rd
# 13                       62 Kings Highway Byp
# 14                               8 Wilson Ave
# 15                                 43 Main St
# 16                            185 Van Dyke St
# 17                                      41-11
# 18                         150 S Wellwood Ave
# 19                            141 Lawrence St
# 20                           2-8 South Street
# 21                                34 River St
# 22                           545 President St
# 23                         1150 Manhattan Ave
# 24                          101 Walnut Street
# 25                                        NaN
# 26                          5 John Walsh Blvd
# 27                              19-33 37th St
# 28                              97 Nassau Ave
# 29                              195 Centre St
# 30                               46-01 5th St
# 31                              101 Luquer St
# 32                            333 Douglass St
# 33                              1904 Surf Ave
# 34                               25 Drexel Dr
# 35                              43-63 11th St
# 36                             623 Sackett St
# 37                      444 Saw Mill River Rd
# 38                       990 Metropolitan Ave
# 39                            206 Thompson St
# 40                                77 Sands St
# 41                             10-28 46th Ave
# 42                               79 N 11th St
# 43                                4 Alsan Way
# 44                               12 Vandam St
# 45                             1539 Covert St
# 46                          415 Beach 72nd St
# 47                                905 Line St
# 48                        400 Union Square Dr
# 49  150 Bay Street, Commercial Side, Suite 2a
#
#                           crossStreet        lat        lng  \
# 0                             2nd Ave  40.657415 -74.006967
# 1   between Willow Ave and Walnut Ave  40.801774 -73.910297
# 2                                 NaN  41.200338 -73.107288
# 3                                 NaN  40.729238 -74.380353
# 4                                 NaN  41.501543 -73.962993
# 5                        Wyckoff Ave.  40.696225 -73.904225
# 6                          Leonard St  40.718573 -73.948276
# 7                                 NaN  39.569417 -74.236787
# 8                                 NaN  40.705974 -73.923487
# 9                        Van Brunt St  40.675510 -74.015746
# 10                                NaN  40.855792 -72.816329
# 11                                NaN  41.461172 -74.403103
# 12                                NaN  41.280006 -74.306465
# 13                                NaN  41.318154 -74.284447
# 14                                NaN  40.703562 -73.931009
# 15                                NaN  40.702965 -73.990600
# 16                                NaN  40.677204 -74.018771
# 17                        39th Street  40.746948 -73.925321
# 18                      W Hoffman Ave  40.686451 -73.372406
# 19   btwn Willoughby St & Fulton Mall  40.691685 -73.986218
# 20                                NaN  41.444838 -74.419916
# 21                        at S 1st St  40.715886 -73.966964
# 22                                NaN  40.677513 -73.984741
# 23                                NaN  40.737669 -73.955158
# 24                                NaN  40.817028 -74.211078
# 25                                NaN  40.694382 -74.189405
# 26                                NaN  41.275866 -73.943205
# 27               btwn 19th & 20th Ave  40.778387 -73.901902
# 28           btwn Manhattan & Leonard  40.723924 -73.950392
# 29                   Smith & Court St  40.673790 -73.999134
# 30                        46th Avenue  40.747336 -73.954843
# 31                                NaN  40.677991 -74.001545
# 32                         at 4th Ave  40.679799 -73.982159
# 33                                NaN  40.575189 -73.983991
# 34                      at Fifth Ave.  40.760852 -73.263459
# 35                            12th St  40.750148 -73.948649
# 36             btwn Third & Forth Ave  40.678609 -73.983415
# 37                      at Hunter Ln.  41.070413 -73.813701
# 38     btwn Catherine St & Morgan Ave  40.714494 -73.936422
# 39          btwn 3rd St & Bleecker St  40.728630 -73.999380
# 40                             Jay St  40.700542 -73.987769
# 41                                NaN  40.746553 -73.951438
# 42                       at Wythe Ave  40.721706 -73.957734
# 43                                NaN  40.856411 -74.043245
# 44                                NaN  40.726314 -74.004208
# 45                                NaN  40.695071 -73.903867
# 46                        Amstel Blvd  40.593069 -73.800852
# 47              btwn Packer & Iron St  40.673478 -75.226249
# 48                    at Union Square  40.365228 -74.953888
# 49                    Marin Boulevard  40.720660 -74.040287
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 40.6574153788505,...        44      11232
# 1   [{'label': 'display', 'lat': 40.80177432001329...     17998      10454
# 2   [{'label': 'display', 'lat': 41.2003375, 'lng'...     96835      06460
# 3   [{'label': 'display', 'lat': 40.72923819029399...     32480      07928
# 4   [{'label': 'display', 'lat': 41.50154311094066...     94003      12508
# 5   [{'label': 'display', 'lat': 40.69622528178149...      9695      11385
# 6   [{'label': 'display', 'lat': 40.718573, 'lng':...      8404      11211
# 7   [{'label': 'display', 'lat': 39.56941682974368...    122717      08008
# 8   [{'label': 'display', 'lat': 40.70597434893818...      8878      11237
# 9   [{'label': 'display', 'lat': 40.67551, 'lng': ...      2103      11231
# 10  [{'label': 'display', 'lat': 40.855792, 'lng':...    102812      11949
# 11  [{'label': 'display', 'lat': 41.4611720939688,...     95408        NaN
# 12  [{'label': 'display', 'lat': 41.28000640869140...     73693      10990
# 13  [{'label': 'display', 'lat': 41.318154, 'lng':...     77117      10918
# 14  [{'label': 'display', 'lat': 40.70356207038148...      8212      11237
# 15  [{'label': 'display', 'lat': 40.702965, 'lng':...      5226      11201
# 16  [{'label': 'display', 'lat': 40.67720443389078...      2374      11231
# 17  [{'label': 'display', 'lat': 40.746948, 'lng':...     12100      11104
# 18  [{'label': 'display', 'lat': 40.68645095825195...     53695      11757
# 19  [{'label': 'display', 'lat': 40.69168497474001...      4174      11201
# 20  [{'label': 'display', 'lat': 41.444838, 'lng':...     94217      10940
# 21  [{'label': 'display', 'lat': 40.715886, 'lng':...      7311      11222
# 22  [{'label': 'display', 'lat': 40.67751312255859...      2907      11215
# 23  [{'label': 'display', 'lat': 40.737669, 'lng':...      9924      11222
# 24  [{'label': 'display', 'lat': 40.81702815045148...     24696      07042
# 25  [{'label': 'display', 'lat': 40.69438181580483...     15909      07114
# 26  [{'label': 'display', 'lat': 41.27586599157626...     69018      10566
# 27  [{'label': 'display', 'lat': 40.77838654705832...     16104      11105
# 28  [{'label': 'display', 'lat': 40.72392428315277...      8792      11222
# 29  [{'label': 'display', 'lat': 40.67378997652133...      1913      11231
# 30  [{'label': 'display', 'lat': 40.74733648316199...     10909      11101
# 31  [{'label': 'display', 'lat': 40.67799099076266...      2304      11231
# 32  [{'label': 'display', 'lat': 40.67979901271337...      3242      11217
# 33  [{'label': 'display', 'lat': 40.57518859380483...      9398      11224
# 34  [{'label': 'display', 'lat': 40.76085224107264...     63804      11706
# 35  [{'label': 'display', 'lat': 40.750148, 'lng':...     11413      11101
# 36  [{'label': 'display', 'lat': 40.678609, 'lng':...      3073      11217
# 37  [{'label': 'display', 'lat': 41.07041281192190...     48741      10523
# 38  [{'label': 'display', 'lat': 40.71449430936535...      8698      11211
# 39  [{'label': 'display', 'lat': 40.72863, 'lng': ...      7918      10012
# 40  [{'label': 'display', 'lat': 40.70054204495188...      5039      11201
# 41  [{'label': 'display', 'lat': 40.74655304120232...     10950      11101
# 42  [{'label': 'display', 'lat': 40.7217061985696,...      8256      11249
# 43  [{'label': 'display', 'lat': 40.85641110404696...     22322      07643
# 44  [{'label': 'display', 'lat': 40.726314, 'lng':...      7637      10013
# 45  [{'label': 'display', 'lat': 40.69507055145107...      9667      11385
# 46  [{'label': 'display', 'lat': 40.59306900566265...     18866      11692
# 47  [{'label': 'display', 'lat': 40.67347825547521...    102943      18042
# 48  [{'label': 'display', 'lat': 40.36522820688081...     86480      18938
# 49  [{'label': 'display', 'lat': 40.72065986602712...      7537      07302
#
#     cc       neighborhood              city state        country  \
# 0   US  Greenwood Heights          Brooklyn    NY  United States
# 1   US                NaN             Bronx    NY  United States
# 2   US                NaN           Milford    CT  United States
# 3   US                NaN  Chatham Township    NJ  United States
# 4   US                NaN            Beacon    NY  United States
# 5   US                NaN         Ridgewood    NY  United States
# 6   US                NaN          Brooklyn    NY  United States
# 7   US                NaN       Beach Haven    NJ  United States
# 8   US           Bushwick          Brooklyn    NY  United States
# 9   US                NaN          Brooklyn    NY  United States
# 10  US                NaN        Manorville    NY  United States
# 11  US                NaN        Middletown    NY  United States
# 12  US                NaN           Warwick    NY  United States
# 13  US                NaN           Chester    NY  United States
# 14  US                NaN          Brooklyn    NY  United States
# 15  US              DUMBO          Brooklyn    NY  United States
# 16  US                NaN          Brooklyn    NY  United States
# 17  US                NaN         Sunnyside    NY  United States
# 18  US                NaN       Lindenhurst    NY  United States
# 19  US  Downtown Brooklyn          Brooklyn    NY  United States
# 20  US                NaN        Middletown    NY  United States
# 21  US                NaN          Brooklyn    NY  United States
# 22  US                NaN          Brooklyn    NY  United States
# 23  US                NaN          Brooklyn    NY  United States
# 24  US                NaN         Montclair    NJ  United States
# 25  US                NaN            Newark    NJ  United States
# 26  US                NaN         Peekskill    NY  United States
# 27  US                NaN           Astoria    NY  United States
# 28  US                NaN          Brooklyn    NY  United States
# 29  US    Carroll Gardens          Brooklyn    NY  United States
# 30  US                NaN            Queens    NY  United States
# 31  US    Carroll Gardens          Brooklyn    NY  United States
# 32  US            Gowanus          Brooklyn    NY  United States
# 33  US                NaN          Brooklyn    NY  United States
# 34  US                NaN         Bay Shore    NY  United States
# 35  US                NaN  Long Island City    NY  United States
# 36  US                NaN          Brooklyn    NY  United States
# 37  US                NaN          Elmsford    NY  United States
# 38  US                NaN          Brooklyn    NY  United States
# 39  US                NaN          New York    NY  United States
# 40  US  Downtown Brooklyn          New York    NY  United States
# 41  US      Hunters Point          New York    NY  United States
# 42  US                NaN          Brooklyn    NY  United States
# 43  US                NaN      Little Ferry    NJ  United States
# 44  US                NaN          New York    NY  United States
# 45  US                NaN          New York    NY  United States
# 46  US                NaN      Far Rockaway    NY  United States
# 47  US                NaN            Easton    PA  United States
# 48  US                NaN          New Hope    PA  United States
# 49  US                NaN       Jersey City    NJ  United States
#
#                                      formattedAddress  \
# 0   [52 34th St (2nd Ave), Brooklyn, NY 11232, Uni...
# 1   [856 E 136th St (between Willow Ave and Walnut...
# 2   [40 Bridgeport Ave, Milford, CT 06460, United ...
# 3         [Chatham Township, NJ 07928, United States]
# 4      [7 E Main St, Beacon, NY 12508, United States]
# 5   [1616 George St (Wyckoff Ave.), Ridgewood, NY ...
# 6   [87 Richardson St (Leonard St), Brooklyn, NY 1...
# 7   [830 N Bay Avenue Store #23, Beach Haven, NJ 0...
# 8   [381 Troutman St, Brooklyn, NY 11237, United S...
# 9   [158 Beard St (Van Brunt St), Brooklyn, NY 112...
# 10  [663 Wading River Rd, Manorville, NY 11949, Un...
# 11                    [Middletown, NY, United States]
# 12  [251 State School Rd, Warwick, NY 10990, Unite...
# 13  [62 Kings Highway Byp, Chester, NY 10918, Unit...
# 14  [8 Wilson Ave, Brooklyn, NY 11237, United States]
# 15    [43 Main St, Brooklyn, NY 11201, United States]
# 16  [185 Van Dyke St, Brooklyn, NY 11231, United S...
# 17  [41-11 (39th Street), Sunnyside, NY 11104, Uni...
# 18  [150 S Wellwood Ave (W Hoffman Ave), Lindenhur...
# 19  [141 Lawrence St (btwn Willoughby St & Fulton ...
# 20  [2-8 South Street, Middletown, NY 10940, Unite...
# 21  [34 River St (at S 1st St), Brooklyn, NY 11222...
# 22  [545 President St, Brooklyn, NY 11215, United ...
# 23  [1150 Manhattan Ave, Brooklyn, NY 11222, Unite...
# 24  [101 Walnut Street, Montclair, NJ 07042, Unite...
# 25                  [Newark, NJ 07114, United States]
# 26  [5 John Walsh Blvd, Peekskill, NY 10566, Unite...
# 27  [19-33 37th St (btwn 19th & 20th Ave), Astoria...
# 28  [97 Nassau Ave (btwn Manhattan & Leonard), Bro...
# 29  [195 Centre St (Smith & Court St), Brooklyn, N...
# 30  [46-01 5th St (46th Avenue), Long Island City,...
# 31  [101 Luquer St, Brooklyn, NY 11231, United Sta...
# 32  [333 Douglass St (at 4th Ave), Brooklyn, NY 11...
# 33  [1904 Surf Ave, Brooklyn, NY 11224, United Sta...
# 34  [25 Drexel Dr (at Fifth Ave.), Bay Shore, NY 1...
# 35  [43-63 11th St (12th St), Long Island City, NY...
# 36  [623 Sackett St (btwn Third & Forth Ave), Broo...
# 37  [444 Saw Mill River Rd (at Hunter Ln.), Elmsfo...
# 38  [990 Metropolitan Ave (btwn Catherine St & Mor...
# 39  [206 Thompson St (btwn 3rd St & Bleecker St), ...
# 40  [77 Sands St (Jay St), New York, NY 11201, Uni...
# 41  [10-28 46th Ave, New York, NY 11101, United St...
# 42  [79 N 11th St (at Wythe Ave), Brooklyn, NY 112...
# 43  [4 Alsan Way, Little Ferry, NJ 07643, United S...
# 44  [12 Vandam St, New York, NY 10013, United States]
# 45  [1539 Covert St, New York, NY 11385, United St...
# 46  [415 Beach 72nd St (Amstel Blvd), Far Rockaway...
# 47  [905 Line St (btwn Packer & Iron St), Easton, ...
# 48  [400 Union Square Dr (at Union Square), New Ho...
# 49  [150 Bay Street, Commercial Side, Suite 2a (Ma...
#
#                           id
# 0   5c6f5ada835c9a0039edf02c
# 1   5151c128e4b026975853f870
# 2   5e1e2003b57bd10008a2e101
# 3   572e1b2dcd10a820394a507b
# 4   588fc9eed8f3e90ab908bc48
# 5   57eaf6a7498ee4d106a06ebf
# 6   60303c4749e1267fe66b53ff
# 7   57a52544498e70074cf7a79b
# 8   56f6cd56cd102dca40d553c9
# 9   5ee52222830eaa0008a81c31
# 10  60bba5337f3f8e10f8ba498f
# 11  58333baf88641b2f6bc26878
# 12  5e7770833fe81d0008fe8d2c
# 13  5ec96cb42db3b500089448f9
# 14  60f723b5d509f33db08d0b04
# 15  60b2bddd4750db5eccabd1ae
# 16  5ed3fb92cdc1e20008b35eea
# 17  5fadb74076ca835ffbe52d60
# 18  5cf7c7370d173f002c396300
# 19  5956d1ae6fd626672c705a01
# 20  5dfacb394355ad0008d1622a
# 21  5fa70b4788394a091aa06512
# 22  5e23b9ff6eaec100081d9071
# 23  5d1e7ebfd29cbb0023e08cc7
# 24  5b65b21b1c0b34002b1183de
# 25  4bccbb8a937ca59377a9ab92
# 26  59ebbf3e356b491e43e832b9
# 27  4f68de6bd5fbee32e5f4f3a5
# 28  4b1883b5f964a520b6d323e3
# 29  52eab90a498ee70cbe1ee103
# 30  50244fd4e4b065daa53e03b3
# 31  57376e4b498e7ef603e18c98
# 32  5414d0a6498ea3d31a3c64cf
# 33  5589a67e498ea3b4d67ffbd9
# 34  4daa325543a1128196f2ecc2
# 35  5d0408fc491be7002ca2b754
# 36  5c0b06e4898bdc002c7fdb9e
# 37  4ae31336f964a5204a9021e3
# 38  5a455ff1b8fd9d266f246125
# 39  502f02a7e4b05159d4f3f24d
# 40  59713095dee77066f35b557d
# 41  580bbe6c38fa27d5b5a442cc
# 42  3fd66200f964a5205deb1ee3
# 43  5538ff3c498e27fbb347d2ff
# 44  5e88c7acb223d800080dce56
# 45  5aa8657369e77b5f8bd11618
# 46  576edb14498e125c56070307
# 47  4b43c15bf964a520a3e825e3
# 48  4ad5f46df964a5202a0421e3
# 49  55046643498e89d9f4bf1418

# %%
df = dataframe_cleaned

# %%
df.groupby(['state', 'city'])['name'].count()
# Out:
# state  city
# CT     Milford              1
# NJ     Beach Haven          1
#        Chatham Township     1
#        Jersey City          1
#        Little Ferry         1
#        Montclair            1
#        Newark               1
# NY     Astoria              1
#        Bay Shore            1
#        Beacon               1
#        Bronx                1
#        Brooklyn            19
#        Chester              1
#        Elmsford             1
#        Far Rockaway         1
#        Lindenhurst          1
#        Long Island City     1
#        Manorville           1
#        Middletown           2
#        New York             5
#        Peekskill            1
#        Queens               1
#        Ridgewood            1
#        Sunnyside            1
#        Warwick              1
# PA     Easton               1
#        New Hope             1
# Name: name, dtype: int64

# %% [markdown]
# As expected, a majority of the breweries are located in the NY region, specifically in Brooklyn and Manhattan.

# %% [markdown]
# ### RESULTS

# %% [markdown]
# **VISUALIZING THESE LOCATIONS ON A NYC MAP**

# %%
latitude=40.65774729310345 
longitude=-74.00725812068966
map_nyc = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(df['lat'], df['lng'], df['city']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_nyc)
map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_c857c47adb454d1590f82d132f8c86dc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c857c47adb454d1590f82d132f8c86dc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c857c47adb454d1590f82d132f8c86dc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_c857c47adb454d1590f82d132f8c86dc%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.65774729310345%2C-74.00725812068966%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20 ...

# %% [markdown]
# ### DISCUSSION

# %% [markdown]
# The Tri-borough area of Brooklyn, Manhattan and Queens (including Long Island City) is where the breweries are clustered.
# A location that is able to cover this area presents a valuable opportunity to source 'THE DREG' from these breweries.
#
# Now we have the dreg, what next?
#
# As an extension to the same project, we can use the FourSquare API to get the locations of farms (urban farms), wastewater plants, fisheries and bakeries to explore our business venture.
#
# Here are a few data science problems to solve:
#
#     - Once we have decided which businesses to partner with and selected which breweries to source from, we can solve a route optimizer for the sourcing and delivering processes
#     - If we decide upon more than one business, we have several problems to optimize our sourcing and selling between the different businesses
#     - Design different marketing campaigns for the sourcing breweries and business customers

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# **Not all waste is actually waste that it should end up in a landfill. Useful waste such as kitchen scraps and industrial food production always have other useful applications which needs to be explored and scaled up. This should help clean up the environment a little, stretch our resources to the fullest extent possible and contribute to building the community.**
